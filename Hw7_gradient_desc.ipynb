# %%
import numpy as np
from scipy.io import loadmat
from random import choice

# %%
def prepare_data():
  data = loadmat("movies.mat")
  X = data["Y"]

  return X


def create_X_train(X: np.array, test_samples = 100):
  m, n = X.shape
  X_test = np.zeros((m, n))

  mm = list(range(m))
  nn = list(range(n))
  i = 0

  ab = []

  while i < test_samples:
    a = choice(mm)
    b = choice(nn)

    if X[a, b] != 0:
      X_test[a, b] = X[a, b]
      ab.append([a, b])

      i += 1

  X_train = X - X_test
  return X_train, ab


def create_random_init_UV(users_num, values_num, p):
  U_init = np.random.random(size=(users_num, p))
  V_init = np.random.random(size=(p, values_num))
  return U_init, V_init

def create_init_UV(users_num, values_num, p):

  U_init = np.ones((users_num, p))
  V_init = np.ones((p, values_num))
  return U_init, V_init



def error_fun(X: np.array, U: np.array, V: np.array):
  A = np.dot(U, V) - X
  a = A.flatten()
  return np.dot(a.T, a)



def gradient_U(X: np.array, U: np.array, V: np.array):
  grad = np.zeros(U.shape)
  m, p = U.shape

  for i in range(m):
    for k in range(p):

      temp_vect = (np.dot(U[i, :], V) - X[i, :])*V[k,:]
      grad[i, k] = temp_vect.sum()

  return grad


def gradient_V(X: np.array, U: np.array, V: np.array):
  grad = np.zeros(V.shape)
  p, n = V.shape

  for j in range(n):
    for k in range(p):

      temp_vect = (np.dot(U, V[:, j]) - X[:, j])*U[:,k]
      grad[k, j] = temp_vect.sum()

  return grad


def optimization(
    X: np.array,
    U_init: np.array,
    V_init: np.array,
    alpha0=0.1,
    eps=1e-6,
    max_steps=1000,
):
  U = U_init
  V = V_init
  grad_U = gradient_U(X, U_init, V_init)
  grad_V = gradient_V(X, U_init, V_init)
  norm_grad_U = np.linalg.norm(grad_U)
  norm_grad_V = np.linalg.norm(grad_V)

  steps_counter = 0

  while norm_grad_U > eps and norm_grad_V > eps:

    if steps_counter >= max_steps:
      break

    grad_U = gradient_U(X, U, V)
    U = U - alpha0 * grad_U

    grad_V = gradient_V(X, U, V)
    V = V - alpha0 * grad_V

    steps_counter += 1
    norm_grad_U = np.linalg.norm(grad_U)
    norm_grad_V = np.linalg.norm(grad_V)

  err = error_fun(X, U, V)

  print(
      f"Optimization task is over, number of iterations = {steps_counter}\nobjective function value = {err}\n||gradU|| = {norm_grad_U}\n||gradV|| = {norm_grad_V}\n\n"
  )

  with open("opt.txt", "w") as f:
      print(
          f"Optimization task is over, number of iterations = {steps_counter}\nobjective function value = {err}\n||gradU|| = {norm_grad_U}\n||gradV|| = {norm_grad_V}\n\n",
          file=f,
      )

  return U, V

# %%
X = prepare_data()
users_num, values_num = X.shape
print(f"number of users = {users_num}\nnumber of movies = {values_num}")

X_train, ab = create_X_train(X)
# Out:
# number of users = 1682
# number of movies = 943

# %%
few_steps = 30
errors_few_steps_test = dict()
errors_few_steps_all = dict()
choosen_alphas = dict()

for p in range(1, 31):
  print(f"p = {p}")
  U_init, V_init = create_random_init_UV(users_num=users_num, values_num=values_num, p=p)
  error = error_fun(X_train, U_init, V_init)

  for i in range(100):
    U_init_, V_init_ = create_random_init_UV(users_num=users_num, values_num=values_num, p=p)
    error_ = error_fun(X_train, U_init, V_init)
    if error_ < error:
      U_init = U_init_
      V_init = V_init_
      error = error_

  print(f"initial error = {error}")

  alphas = [0.002, 0.001, 0.0005, 0.0002, 0.0001, 0.00005]

  for alpha in alphas:
    U, V = optimization(X, U_init, V_init, max_steps=2, alpha0=alpha)
    opt_error = error_fun(X_train, U, V)
    if opt_error < error:
      break

  print(f"alpha = {alpha}")
  choosen_alphas[p] = alpha

  U, V = optimization(X, U_init, V_init, max_steps=few_steps, alpha0=alpha)
  errors_few_steps_all[p] = error_fun(X, U, V)

  UV = np.dot(U, V)
  UV_ = UV.round(2)

  comparison = []
  for item in ab:
    a = item[0]
    b = item[1]
    comparison.append((item, X[a, b], UV_[a, b]))

    comp_err = 0
    for row in comparison:
      comp_err += (row[1] - row[2])**2

    errors_few_steps_test[p] = comp_err

  try:
    if errors_few_steps_test[p] > errors_few_steps_test[p-1] and errors_few_steps_all[p] > errors_few_steps_all[p-1] and choosen_alphas[p] == choosen_alphas[p-1]:
      break
  except:
    pass
# Out:
# p = 1
# initial error = 1373573.0869821268
# Optimization task is over, number of iterations = 2
# objective function value = 968095.1951625623
# ||gradU|| = 6147.889911295061
# ||gradV|| = 2350.8688272310646
#
#
# alpha = 0.002
# Optimization task is over, number of iterations = 26
# objective function value = 962292.5616368802
# ||gradU|| = 6.389466382049478e-07
# ||gradV|| = 3.6209073391238087e-06
#
#
# p = 2
# initial error = 1585427.438936211
# Optimization task is over, number of iterations = 2
# objective function value = 969494.9612036982
# ||gradU|| = 4818.047047389741
# ||gradV|| = 2860.5534239382164
#
#
# alpha = 0.002
# Optimization task is over, number of iterations = 30
# objective function value = 902374.8675791748
# ||gradU|| = 28.10709809848717
# ||gradV|| = 25.42028602511304
#
#
# p = 3
# initial error = 1942060.9663897818
# Optimization task is over, number of iterations = 2
# objective function value = 994949.1497547934
# ||gradU|| = 8617.839733344177
# ||gradV|| = 3740.9901686407816
#
#
# alpha = 0.002
# Optimization task is over, number of iterations = 30
# objective function value = 854899.9682236766
# ||gradU|| = 26.314886022364213
# ||gradV|| = 21.75247878617239
#
#
# p = 4
# initial error = 2486695.375246404
# Optimization task is over, number of iterations = 2
# objective function value = 42614283508.44267
# ||gradU|| = 84410.27717524362
# ||gradV|| = 794795.5549868735
#
#
# Optimization task is over, number of iterations = 2
# objective function value = 1031855.3805220742
# ||gradU|| = 2559.1200883482957
# ||gradV|| = 5573.29230338598
#
#
# alpha = 0.001
# Optimization task is over, number of iterations = 30
# objective function value = 841905.4477420844
# ||gradU|| = 738.9775322367382
# ||gradV|| = 551.063505295581
#
#
# p = 5
# initial error = 3348371.32813257
# Optimization task is over, number of iterations = 2
# objective function value = 1.0095635158630486e+22
# ||gradU|| = 3059215.36543256
# ||gradV|| = 8292531565.489252
#
#
# Optimization task is over, number of iterations = 2
# objective function value = 1058870.903147028
# ||gradU|| = 12822.401139416683
# ||gradV|| = 6060.414023650435
#
#
# alpha = 0.001
# Optimization task is over, number of iterations = 30
# objective function value = 821079.4708242199
# ||gradU|| = 1055.8347061302898
# ||gradV|| = 749.3619220460386
#
#
# p = 6
# initial error = 4372161.158192353
# Optimization task is over, number of iterations = 2
# objective function value = 6.022091120263338e+28
# ||gradU|| = 29805419.31000789
# ||gradV|| = 2061397447512.5752
#
#
# Optimization task is over, number of iterations = 2
# objective function value = 1200306.035090414
# ||gradU|| = 13954.148672752604
# ||gradV|| = 5116.234202391863
#
#
# alpha = 0.001
# Optimization task is over, number of iterations = 30
# objective function value = 815093.5134400809
# ||gradU|| = 1301.084323983037
# ||gradV|| = 964.9152240117803
#
#
# p = 7
# initial error = 5521829.806851013
# Optimization task is over, number of iterations = 2
# objective function value = 8.90622575742616e+33
# ||gradU|| = 170408275.24893403
# ||gradV|| = 138499717575440.58
#
#
# Optimization task is over, number of iterations = 2
# objective function value = 1360251.9236474093
# ||gradU|| = 5934.227943598279
# ||gradV|| = 6135.023699935157
#
#
# alpha = 0.001
# Optimization task is over, number of iterations = 30
# objective function value = 813007.8718312707
# ||gradU|| = 1092.4734281542624
# ||gradV|| = 740.1569845772922
#
#
# p = 8
# initial error = 6829707.636731861
# Optimization task is over, number of iterations = 2
# objective function value = 6.109511944244383e+37
# ||gradU|| = 622272710.4373516
# ||gradV|| = 3140619587323045.5
#
#
# Optimization task is over, number of iterations = 2
# objective function value = 11697785915.380577
# ||gradU|| = 170639.96654314245
# ||gradV|| = 931526.1614277882
#
#
# Optimization task is over, number of iterations = 2
# objective function value = 1148555.9255513195
# ||gradU|| = 3298.4966432404262
# ||gradV|| = 5127.294624695184
#
#
# alpha = 0.0005
# Optimization task is over, number of iterations = 30
# objective function value = 908674.3318636641
# ||gradU|| = 1835.889676292794
# ||gradV|| = 1591.29668209535
#
#
# p = 9
# initial error = 8454660.81929964
# Optimization task is over, number of iterations = 2
# objective function value = 3.093624462747145e+41
# ||gradU|| = 2173561068.7010026
# ||gradV|| = 6.397656336838436e+16
#
#
# Optimization task is over, number of iterations = 2
# objective function value = 2.7089751541763386e+17
# ||gradU|| = 1556953.2059569214
# ||gradV|| = 348862010.81684446
#
#
# Optimization task is over, number of iterations = 2
# objective function value = 1155740.974899944
# ||gradU|| = 12038.882788676887
# ||gradV|| = 5095.508486197908
#
#
# alpha = 0.0005
# Optimization task is over, number of iterations = 30
# objective function value = 898204.8059976891
# ||gradU|| = 1845.8267195763274
# ||gradV|| = 1581.6917199673574
#
#
# p = 10
# initial error = 10403493.042301299
# Optimization task is over, number of iterations = 2
# objective function value = 7.695196683596986e+44
# ||gradU|| = 6841169822.727091
# ||gradV|| = 1.0137407527612602e+18
#
#
# Optimization task is over, number of iterations = 2
# objective function value = 3.0159563745095475e+22
# ||gradU|| = 8286123.045321532
# ||gradV|| = 21173966525.19242
#
#
# Optimization task is over, number of iterations = 2
# objective function value = 1172021.8711534182
# ||gradU|| = 29476.055051592786
# ||gradV|| = 5327.163204172804
#
#
# alpha = 0.0005
# Optimization task is over, number of iterations = 30
# objective function value = 889362.629373167
# ||gradU|| = 1594.7917509055258
# ||gradV|| = 1432.6336974880535
#
#
# p = 11
# initial error = 12116182.8900022
# Optimization task is over, number of iterations = 2
# objective function value = 2.208490828172421e+47
# ||gradU|| = 15686887697.220356
# ||gradV|| = 7.489533577636768e+18
#
#
# Optimization task is over, number of iterations = 2
# objective function value = 6.139197285419922e+25
# ||gradU|| = 25154298.81103303
# ||gradV|| = 312754159209.72906
#
#
# Optimization task is over, number of iterations = 2
# objective function value = 1200223.5669822923
# ||gradU|| = 39132.60796991646
# ||gradV|| = 5256.35296789806
#
#
# alpha = 0.0005
# Optimization task is over, number of iterations = 30
# objective function value = 896588.3975218739
# ||gradU|| = 1964.6145217949725
# ||gradV|| = 1699.6249291876009
#
#
# p = 12
# initial error = 14292830.92172647
# Optimization task is over, number of iterations = 2
# objective function value = 6.820771263073839e+49
# ||gradU|| = 36360457956.49109
# ||gradV|| = 5.67844325770929e+19
#
#
# Optimization task is over, number of iterations = 2
# objective function value = 8.269439199387355e+28
# ||gradU|| = 72152065.0197817
# ||gradV|| = 3992316935813.7676
#
#
# Optimization task is over, number of iterations = 2
# objective function value = 1423836.7135004683
# ||gradU|| = 36480.51963996648
# ||gradV|| = 4895.3541721014735
#
#
# alpha = 0.0005
# Optimization task is over, number of iterations = 30
# objective function value = 887546.4977687591
# ||gradU|| = 1658.6926092795034
# ||gradV|| = 1410.7738206563163
#
#
# p = 13
# initial error = 17111345.01560111
# Optimization task is over, number of iterations = 2
# objective function value = 5.679728122398845e+52
# ||gradU|| = 97441448017.96565
# ||gradV|| = 6.114499179226725e+20
#
#
# Optimization task is over, number of iterations = 2
# objective function value = 3.070021670472122e+32
# ||gradU|| = 240431014.12049845
# ||gradV|| = 72921042789320.14
#
#
# Optimization task is over, number of iterations = 2
# objective function value = 1451287.927133387
# ||gradU|| = 8202.281762497032
# ||gradV|| = 18591.441785344676
#
#
# alpha = 0.0005
# Optimization task is over, number of iterations = 30
# objective function value = 894460.8020453453
# ||gradU|| = 1910.6211316230567
# ||gradV|| = 1662.5363341996315
#
#
# p = 14
# initial error = 19429624.409131587
# Optimization task is over, number of iterations = 2
# objective function value = 3.599767914069985e+54
# ||gradU|| = 179054801606.31488
# ||gradV|| = 2.649060010368385e+21
#
#
# Optimization task is over, number of iterations = 2
# objective function value = 3.93389313496377e+34
# ||gradU|| = 489688647.17579144
# ||gradV|| = 405175605550032.44
#
#
# Optimization task is over, number of iterations = 2
# objective function value = 1383450.4856582852
# ||gradU|| = 9048.672782798425
# ||gradV|| = 15935.362774632407
#
#
# alpha = 0.0005
# Optimization task is over, number of iterations = 30
# objective function value = 890245.8735337368
# ||gradU|| = 1873.1014482004553
# ||gradV|| = 1613.997454026916
#
#
# p = 15
# initial error = 22294596.690228708
# Optimization task is over, number of iterations = 2
# objective function value = 2.7944537544600596e+56
# ||gradU|| = 338961823438.9687
# ||gradV|| = 1.2329287692039871e+22
#
#
# Optimization task is over, number of iterations = 2
# objective function value = 5.754984602496649e+36
# ||gradU|| = 1017091967.2488513
# ||gradV|| = 2359094585877573.0
#
#
# Optimization task is over, number of iterations = 2
# objective function value = 1239235.1137120211
# ||gradU|| = 120240.02828172146
# ||gradV|| = 5210.153994198928
#
#
# alpha = 0.0005
# Optimization task is over, number of iterations = 30
# objective function value = 877757.5430804656
# ||gradU|| = 2009.1740154670722
# ||gradV|| = 1711.7258282480454
#
#
# p = 16
# initial error = 25060073.59346608
# Optimization task is over, number of iterations = 2
# objective function value = 1.748476444594644e+58
# ||gradU|| = 621517558983.554
# ||gradV|| = 5.318837011028972e+22
#
#
# Optimization task is over, number of iterations = 2
# objective function value = 6.569841920444517e+38
# ||gradU|| = 2036775802.570264
# ||gradV|| = 1.25858170764997e+16
#
#
# Optimization task is over, number of iterations = 2
# objective function value = 511403084012.7803
# ||gradU|| = 634504.0985410174
# ||gradV|| = 5970415.675432222
#
#
# Optimization task is over, number of iterations = 2
# objective function value = 1361484.6157302796
# ||gradU|| = 57177.312147125784
# ||gradV|| = 7293.185699785414
#
#
# alpha = 0.0002
# Optimization task is over, number of iterations = 30
# objective function value = 1024918.4003884463
# ||gradU|| = 1658.3280582269326
# ||gradV|| = 2986.41381776195
#
#
# p = 17
# initial error = 28139583.28715749
# Optimization task is over, number of iterations = 2
# objective function value = 7.0689822819110675e+59
# ||gradU|| = 1069131380147.8265
# ||gradV|| = 1.966018028119842e+23
#
#
# Optimization task is over, number of iterations = 2
# objective function value = 4.1250131048637944e+40
# ||gradU|| = 3737290434.703012
# ||gradV|| = 5.43481169808545e+16
#
#
# Optimization task is over, number of iterations = 2
# objective function value = 3077935701871505.0
# ||gradU|| = 1948143.3380549795
# ||gradV|| = 124590314.56044188
#
#
# Optimization task is over, number of iterations = 2
# objective function value = 1314233.5799835713
# ||gradU|| = 52763.100988720835
# ||gradV|| = 6420.098207048666
#
#
# alpha = 0.0002
# Optimization task is over, number of iterations = 30
# objective function value = 1025097.0846979222
# ||gradU|| = 2015.485480790545
# ||gradV|| = 3072.807785192936

# %%
print(f"errors_few_steps_test = \n{errors_few_steps_test}")
print(f"errors_few_steps_all = \n{errors_few_steps_all}")
print(f"choosen_alphas = \n{choosen_alphas}")
# Out:
# errors_few_steps_test =
# {1: 812.8125000000002, 2: 759.7456, 3: 701.5741000000002, 4: 692.1294000000001, 5: 655.6777999999999, 6: 659.0926, 7: 640.5875999999998, 8: 759.7881000000002, 9: 745.072, 10: 739.2710000000001, 11: 738.1588, 12: 736.6300000000001, 13: 717.0278000000003, 14: 731.6779000000002, 15: 726.4527, 16: 855.6733999999997, 17: 870.2684}
# errors_few_steps_all =
# {1: 962292.5616368802, 2: 902374.8675791748, 3: 854899.9682236766, 4: 841905.4477420844, 5: 821079.4708242199, 6: 815093.5134400809, 7: 813007.8718312707, 8: 908674.3318636641, 9: 898204.8059976891, 10: 889362.629373167, 11: 896588.3975218739, 12: 887546.4977687591, 13: 894460.8020453453, 14: 890245.8735337368, 15: 877757.5430804656, 16: 1024918.4003884463, 17: 1025097.0846979222}
# choosen_alphas =
# {1: 0.002, 2: 0.002, 3: 0.002, 4: 0.001, 5: 0.001, 6: 0.001, 7: 0.001, 8: 0.0005, 9: 0.0005, 10: 0.0005, 11: 0.0005, 12: 0.0005, 13: 0.0005, 14: 0.0005, 15: 0.0005, 16: 0.0002, 17: 0.0002}

# %%
p = 7

U_init, V_init = create_random_init_UV(users_num=users_num, values_num=values_num, p=p)
error = error_fun(X_train, U_init, V_init)

for i in range(100):
  U_init_, V_init_ = create_random_init_UV(users_num=users_num, values_num=values_num, p=p)
  error_ = error_fun(X_train, U_init, V_init)
  if error_ < error:
    U_init = U_init_
    V_init = V_init_
    error = error_

print(f"initial error = {error}")

alpha = choosen_alphas[p]
print(f"alpha = {alpha}")

U, V = optimization(X, U_init, V_init, max_steps=3000, alpha0=alpha)

UV = np.dot(U, V)
UV_ = UV.round(2)
# Out:
# initial error = 5569200.933679744
# alpha = 0.001
# Optimization task is over, number of iterations = 3000
# objective function value = 767228.6117159193
# ||gradU|| = 0.004528120138419177
# ||gradV|| = 0.0021715337939638845

# %%
comparison = []
for item in ab:
  a = item[0]
  b = item[1]
  comparison.append((UV_[a, b], X[a, b], a, b))

  comp_err = 0
  for row in comparison:
    comp_err += (row[1] - row[2])**2

print(f"test error = {comp_err}")
# Out:
# test error = 22545295

# %%
with open("X_train.txt", "w") as f:
    for row in list(X_train):
        print(str(list(row)), file=f)

with open("X.txt", "w") as f:
    for row in list(X):
        print(str(list(row)), file=f)

with open("UV.txt", "w") as f:
    for row in list(UV_):
        print(str(list(row)), file=f)

# %%
comparison.sort(reverse=True)

for row in comparison:
  print(row)
# Out:
# (5.13, 5, 0, 329)
# (4.4, 2, 312, 682)
# (4.27, 3, 257, 935)
# (4.24, 4, 94, 294)
# (4.03, 4, 236, 183)
# (4.02, 5, 131, 397)
# (3.72, 4, 222, 302)
# (3.72, 4, 196, 333)
# (3.67, 3, 94, 647)
# (3.67, 3, 76, 392)
# (3.59, 5, 194, 157)
# (3.52, 3, 299, 633)
# (3.46, 5, 301, 531)
# (3.44, 4, 160, 41)
# (3.39, 3, 482, 390)
# (3.36, 5, 124, 346)
# (3.29, 4, 171, 637)
# (3.06, 5, 317, 710)
# (2.98, 3, 299, 89)
# (2.95, 5, 96, 86)
# (2.85, 4, 110, 795)
# (2.66, 5, 356, 209)
# (2.61, 4, 122, 290)
# (2.59, 4, 256, 921)
# (2.57, 3, 275, 213)
# (2.54, 4, 315, 531)
# (2.51, 4, 484, 377)
# (2.49, 5, 500, 12)
# (2.36, 4, 791, 183)
# (2.32, 5, 630, 534)
# (2.3, 5, 504, 746)
# (2.24, 2, 762, 398)
# (2.13, 5, 171, 396)
# (2.13, 3, 244, 350)
# (2.06, 3, 327, 190)
# (1.99, 4, 422, 620)
# (1.98, 2, 87, 451)
# (1.96, 3, 403, 279)
# (1.93, 4, 211, 183)
# (1.82, 3, 548, 434)
# (1.72, 2, 418, 842)
# (1.69, 2, 615, 233)
# (1.65, 4, 133, 464)
# (1.61, 4, 59, 12)
# (1.59, 3, 596, 74)
# (1.56, 3, 53, 891)
# (1.51, 5, 41, 335)
# (1.48, 5, 662, 532)
# (1.45, 5, 9, 710)
# (1.45, 3, 327, 901)
# (1.44, 5, 125, 716)
# (1.43, 1, 289, 681)
# (1.31, 5, 523, 746)
# (1.24, 4, 84, 404)
# (1.22, 3, 417, 877)
# (1.14, 4, 300, 498)
# (1.11, 2, 410, 473)
# (1.09, 4, 921, 275)
# (1.07, 4, 701, 893)
# (1.07, 2, 300, 508)
# (0.99, 3, 28, 196)
# (0.95, 5, 735, 535)
# (0.91, 4, 503, 709)
# (0.91, 3, 254, 575)
# (0.9, 3, 1097, 415)
# (0.87, 2, 229, 81)
# (0.85, 4, 517, 874)
# (0.83, 4, 320, 445)
# (0.8, 5, 546, 341)
# (0.79, 3, 332, 75)
# (0.77, 2, 714, 108)
# (0.75, 3, 287, 644)
# (0.74, 5, 305, 790)
# (0.72, 4, 1167, 710)
# (0.7, 5, 411, 886)
# (0.63, 4, 549, 933)
# (0.62, 4, 140, 561)
# (0.61, 4, 57, 236)
# (0.59, 3, 648, 773)
# (0.59, 3, 100, 405)
# (0.58, 4, 1054, 392)
# (0.55, 2, 353, 98)
# (0.49, 4, 528, 503)
# (0.48, 4, 332, 298)
# (0.47, 3, 261, 925)
# (0.44, 1, 457, 67)
# (0.37, 4, 81, 114)
# (0.37, 3, 992, 202)
# (0.34, 3, 523, 263)
# (0.33, 4, 442, 4)
# (0.31, 3, 872, 551)
# (0.3, 2, 828, 93)
# (0.28, 4, 951, 44)
# (0.28, 2, 1162, 273)
# (0.21, 4, 329, 643)
# (0.2, 4, 33, 550)
# (0.06, 4, 712, 572)
# (0.03, 4, 919, 13)
# (-0.06, 5, 64, 493)
# (-0.64, 4, 125, 639)

# %% [markdown]
# Dokonano rozkładu macierzy X o rozmiarze 1682x943 na macierze U i V o rozmiarach odpowiednio 1682x7 i 7x943, minimalizując normę Frobeniusa ||UV - X|| bez regularyzacji. Optymalne rozwiązanie zostało znalezione. Mimo to zbudowany model nie działa dobrze. Być może udałoby się uzyskać poprawę jakościu modelu przy znacznym zwiększeniu wymiaru macierzy U i V. Niestety sprawdzenie tego jest bardzo kosztowne obliczenowo przy stosowaniu metody gradientu prostego do rozwiązania zadania optymalizacji.
